# %% [markdown]
# # Optional Lab: 使用逻辑回归进行分类
#
# 在这个实验室中，你将对比回归和分类。

# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from lab_utils_common import dlc, plot_data
from plt_one_addpt_onclick import plt_one_addpt_onclick
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# ## 分类问题
# <img align="left" src="../work/images/C1_W3_Classification.png" style=" width:380px; padding: 10px; " > 分类问题的示例包括：将电子邮件识别为垃圾邮件或非垃圾邮件，或者确定肿瘤是恶性还是良性。特别是，这些是二元分类的示例，其中有两种可能的结果。结果可以用“正”/“负”对来描述，例如“是”/“否”、“真”/“假”或“1”/“0”。
#
# 分类数据集的图表通常使用符号来表示一个示例的结果。在下面的图表中，“X”用于表示正值，而“O”表示负值结果。

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])
X_train2 = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train2 = np.array([0, 0, 0, 1, 1, 1])

# %%
pos = y_train == 1
neg = y_train == 0

fig,ax = plt.subplots(1,2,figsize=(8,3))
#plot 1, single variable
ax[0].scatter(x_train[pos], y_train[pos], marker='x', s=80, c = 'red', label="y=1")
ax[0].scatter(x_train[neg], y_train[neg], marker='o', s=100, label="y=0", facecolors='none', 
              edgecolors=dlc["dlblue"],lw=3)

ax[0].set_ylim(-0.08,1.1)
ax[0].set_ylabel('y', fontsize=12)
ax[0].set_xlabel('x', fontsize=12)
ax[0].set_title('one variable plot')
ax[0].legend()

#plot 2, two variables
plot_data(X_train2, y_train2, ax[1])
ax[1].axis([0, 4, 0, 4])
ax[1].set_ylabel('$x_1$', fontsize=12)
ax[1].set_xlabel('$x_0$', fontsize=12)
ax[1].set_title('two variable plot')
ax[1].legend()
plt.tight_layout()
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# 上述图表中的注意事项：
# - 在单变量图表中，正结果同时以红色“X”和 y = 1 表示。负结果是蓝色“O”，位于 y = 0 处。
#    - 回想在线性回归的情况下，y 不会局限于两个值，而是可以是任何值。
# - 在双变量图表中，y 轴不可用。正结果以红色“X”表示，而负结果使用蓝色“O”符号。
#     - 回想在多变量线性回归的情况下，y 不会局限于两个值，类似的图表将是三维的。

# %% [markdown]
# ## 线性回归方法
# 在上周，你应用线性回归构建了一个预测模型。现在让我们使用讲座中描述的简单示例在此尝试该方法。该模型将根据肿瘤大小预测肿瘤是良性还是恶性。请尝试以下操作：
# - 点击“运行线性回归”以找到给定数据的最佳线性回归模型。
#     - 请注意，所得线性模型与数据**不**太匹配。
# 改善结果的一种方法是应用一个*阈值*。
# - 勾选“切换 0.5 阈值”框以显示应用阈值时的预测。
#     - 这些预测看起来不错，预测与数据匹配。
# - 重要：现在，在最右侧的大肿瘤大小范围（接近 10）中添加更多“恶性”数据点，然后重新运行线性回归。
#     - 现在，模型预测较大的肿瘤，但 x = 3 处的数据点被错误预测！
# - 要清除/更新图表，请重新运行包含绘图命令的单元格。

# %% [markdown]
# 上面的例子表明线性模型不足以对分类数据进行建模。该模型可以如下面的实验所述进行扩展。

# %%
w_in = np.zeros((1))
b_in = 0
plt.close('all') 
addpt = plt_one_addpt_onclick( x_train,y_train, w_in, b_in, logistic=False)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# ## 恭喜！
# 在这个实验中你：
# - 探索了分类数据集和绘图。
# - 确定了线性回归对于逻辑回归是不够的。
