# %% [markdown]
# # Optional Lab:  Brief Introduction to Python and Jupyter Notebooks
# 欢迎来到第一个实验！
# 实验可用于：
# - 提供信息 —— 就像这个笔记本一样。
# - 通过实际示例强化讲座材料。
# - 提供分级实验中使用的例程的有效示例。

# %% [markdown]
# ## Goals
# 在这个实验室中，你将：
#
# - 简要了解 Jupyter 笔记本。
# - 参观 Jupyter 笔记本。
# - 了解标记单元格和代码单元格之间的区别。
# - 练习一些基本的 Python。

# %% [markdown]
# 熟悉 Jupyter 笔记本的最简单方法是通过 “帮助” 菜单中的上述游览选项进行游览。

# %% [markdown]
# <figure>
#     <center> <img src="../work/images/C1W1L1_Tour.PNG"  alt='missing' width="400"  ><center/>
# <figure/>

# %% [markdown]
# Jupyter 笔记本在本课程中有两种类型的单元格。像这样包含文档的单元格称为Markdown Cells。这个名称源自单元格中使用的简单格式语言。你不需要生成 `Markdown 单元格`。理解下面图形中显示的`cell pulldown`很有用。偶尔，一个单元格会处于错误的模式，你可能需要将其恢复到正确的状态。

# %% [markdown]
# <figure>
#    <img src="../work/images/C1W1L1_Markdown.PNG"  alt='missing' width="400"  >
# <figure/>

# %% [markdown]
# 另一种类型的单元格是 “代码单元格”，你将在其中编写代码：

# %%
#This is  a 'Code' Cell
print("This is 代码单元格")
# Out:
# This is 代码单元格

# %% [markdown]
# ## Python
# You can write your code in the code cells.
# To run the code, select the cell and either
# - hold the shift-key down and hit 'enter' or 'return'
# - click the 'run' arrow above
# <figure>
#     <img src="../work/images/C1W1L1_Run.PNG"  width="400"  >
# <figure/>

# %% [markdown]
# ### Print statement
# Print statements will generally use the python f-string style.  打印语句通常会使用 Python 的 f 字符串风格。
#
# Try creating your own print in the following cell.  在下面的单元格中尝试创建你自己的打印语句。
#
# Try both methods of running the cell.   尝试两种运行单元格的方法。

# %%
# print statements
variable = "right in the strings!"
print(f"f strings allow you to embed variables {variable}")
# Out:
# f strings allow you to embed variables right in the strings!

# %% [markdown]
# # Congratulations!
# You now know how to find your way around a Jupyter Notebook.
